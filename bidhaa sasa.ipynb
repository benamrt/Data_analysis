# %%
import pandas as pd
import numpy as np
import datetime

# %%
bidhaa=pd.read_csv("C:/pyfiles/bidhaa_sasa .csv")

# %%
bidhaa.shape
# Out:
# (31516, 30)

# %%
bidhaa_df=bidhaa.copy()

# %%
bidhaa_df=bidhaa.copy()

# %%
bidhaa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31516 entries, 0 to 31515
# Data columns (total 30 columns):
# Client ID             31516 non-null object
# Client name           0 non-null float64
# DOB                   31502 non-null object
# AGE                   31516 non-null float64
# ID Card               6665 non-null object
# Gender                31516 non-null object
# Account               31516 non-null int64
# Branch                31516 non-null object
# Product               31516 non-null object
# Loan Principal        31516 non-null object
# Interest              31516 non-null int64
# Down Payment          31516 non-null object
# Total amount          31516 non-null object
# Principal             31516 non-null object
# Interest.1            31516 non-null int64
# Fees                  31516 non-null int64
# Total                 31516 non-null object
# Prepayment            31516 non-null object
# Loan Officer          31516 non-null object
# Cycle                 30823 non-null float64
# Disbursed Date        31516 non-null object
# Installments          31516 non-null int64
# Loan Frequency        31516 non-null int64
# Loan Frequency 2      31516 non-null object
# Status                31516 non-null object
# TRP                   31313 non-null object
# Group ID              31516 non-null object
# Final Payment Date    18764 non-null object
# Arrear Amount         31516 non-null object
# Days in Arrears       5107 non-null float64
# dtypes: float64(4), int64(6), object(20)
# memory usage: 7.2+ MB

# %%
bidhaa_df.isna().sum()
# Out:
# Client ID                 0
# Client name           31516
# DOB                      14
# AGE                       0
# ID Card               24851
# Gender                    0
# Account                   0
# Branch                    0
# Product                   0
# Loan Principal            0
# Interest                  0
# Down Payment              0
# Total amount              0
# Principal                 0
# Interest.1                0
# Fees                      0
# Total                     0
# Prepayment                0
# Loan Officer              0
# Cycle                   693
# Disbursed Date            0
# Installments              0
# Loan Frequency            0
# Loan Frequency 2          0
# Status                    0
# TRP                     203
# Group ID                  0
# Final Payment Date    12752
# Arrear Amount             0
# Days in Arrears       26409
# dtype: int64

# %%
bidhaa_df.columns
# Out:
# Index(['Client ID', 'Client name', 'DOB', 'AGE', 'ID Card', 'Gender',
#        'Account', 'Branch', 'Product', 'Loan Principal', 'Interest',
#        'Down Payment', 'Total amount', 'Principal', 'Interest.1', 'Fees',
#        'Total ', 'Prepayment', 'Loan Officer', 'Cycle', 'Disbursed Date',
#        'Installments', 'Loan Frequency', 'Loan Frequency 2', 'Status', 'TRP',
#        'Group ID', 'Final Payment Date', 'Arrear Amount', 'Days in Arrears'],
#       dtype='object')

# %%
bidhaa_df.drop(['Client name','ID Card','Days in Arrears'],axis=1,inplace=True)

# %%
bidhaa_df['TRP'].fillna('0%',inplace=True)

# %%
bidhaa_df['Cycle'].fillna('0',inplace=True)

# %%
dob=list(bidhaa_df['DOB'].mode())[0]

# %%
bidhaa_df['DOB'].fillna(dob,inplace=True)

# %%
bidhaa_df.isna().sum()
# Out:
# Client ID                 0
# DOB                       0
# AGE                       0
# Gender                    0
# Account                   0
# Branch                    0
# Product                   0
# Loan Principal            0
# Interest                  0
# Down Payment              0
# Total amount              0
# Principal                 0
# Interest.1                0
# Fees                      0
# Total                     0
# Prepayment                0
# Loan Officer              0
# Cycle                     0
# Disbursed Date            0
# Installments              0
# Loan Frequency            0
# Loan Frequency 2          0
# Status                    0
# TRP                       0
# Group ID                  0
# Final Payment Date    12752
# Arrear Amount             0
# dtype: int64

# %%
f_d=list(bidhaa_df['Final Payment Date'].mode())[0]

# %%
bidhaa_df['Final Payment Date'].fillna(f_d,inplace=True)

# %%
bidhaa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31516 entries, 0 to 31515
# Data columns (total 27 columns):
# Client ID             31516 non-null object
# DOB                   31516 non-null object
# AGE                   31516 non-null float64
# Gender                31516 non-null object
# Account               31516 non-null int64
# Branch                31516 non-null object
# Product               31516 non-null object
# Loan Principal        31516 non-null object
# Interest              31516 non-null int64
# Down Payment          31516 non-null object
# Total amount          31516 non-null object
# Principal             31516 non-null object
# Interest.1            31516 non-null int64
# Fees                  31516 non-null int64
# Total                 31516 non-null object
# Prepayment            31516 non-null object
# Loan Officer          31516 non-null object
# Cycle                 31516 non-null object
# Disbursed Date        31516 non-null object
# Installments          31516 non-null int64
# Loan Frequency        31516 non-null int64
# Loan Frequency 2      31516 non-null object
# Status                31516 non-null object
# TRP                   31516 non-null object
# Group ID              31516 non-null object
# Final Payment Date    31516 non-null object
# Arrear Amount         31516 non-null object
# dtypes: float64(1), int64(6), object(20)
# memory usage: 6.5+ MB

# %%
product=bidhaa_df[['Client ID','Product','Cycle']]

# %%
product.head()
# Out:
#          Client ID Product Cycle
# 0  0008-0056-17323    BORA     1
# 1  0008-0056-17324    BORA     1
# 2  0008-0056-17326    BORA     1
# 3  0008-0056-17327    BORA     1
# 4  0008-0056-17328    BORA     1

# %%
bidhaa_df.corr()
# Out:
#                      AGE   Account  Interest  Interest.1  Fees  Installments  \
# AGE             1.000000  0.000826       NaN         NaN   NaN      0.072960
# Account         0.000826  1.000000       NaN         NaN   NaN      0.158463
# Interest             NaN       NaN       NaN         NaN   NaN           NaN
# Interest.1           NaN       NaN       NaN         NaN   NaN           NaN
# Fees                 NaN       NaN       NaN         NaN   NaN           NaN
# Installments    0.072960  0.158463       NaN         NaN   NaN      1.000000
# Loan Frequency       NaN       NaN       NaN         NaN   NaN           NaN
#
#                 Loan Frequency
# AGE                        NaN
# Account                    NaN
# Interest                   NaN
# Interest.1                 NaN
# Fees                       NaN
# Installments               NaN
# Loan Frequency             NaN

# %%
product.sort_values('Cycle',ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4dc1de30264e> in <module>
# ----> 1 product.sort_values('Cycle',ascending=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4425
#    4426             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 4427                                na_position=na_position)
#    4428
#    4429         new_data = self._data.take(indexer,
#
# ~\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     253         non_nans = non_nans[::-1]
#     254         non_nan_idx = non_nan_idx[::-1]
# --> 255     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     256     if not ascending:
#     257         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
product_choice=bidhaa[['DOB','Product']]

# %%
product_choice.head()
# Out:
#           DOB Product
# 0    1/1/1965    BORA
# 1   5/15/1953    BORA
# 2    1/1/1954    BORA
# 3  12/30/1986    BORA
# 4    1/2/1978    BORA

# %%
now=datetime.datetime.today()

# %%
product_choice['DOB'] = pd.to_datetime(product_choice['DOB'], errors='coerce')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%