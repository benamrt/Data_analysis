# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv('C:/pyfiles/company_sales_data.csv')

# %%
sales.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#Exercise 1: Read Total profit of all months and show it using a bar (barh for horizontal bars) plot
month_number=sales['month_number']
total_profit=sales['total_profit']
plt.bar(month_number,total_profit)
plt.xlabel('month_number')
plt.ylabel('total_profit')
plt.show()

# %%
#same plot as above using a line plot
month_number=sales['month_number']
total_profit=sales['total_profit']
plt.plot(month_number,total_profit,color='b',marker='o',linestyle='-',linewidth=4)
plt.xlabel('month_number')
plt.ylabel('total_profit')
plt.show()

# %%
#Exercise Question 2: Get Total profit of all months and show line plot with the following Style properties
#Line Style dotted and Line-color should be red
#Show legend at the lower right location.
#X label name = Month Number
#Y label name = Sold units number
#Add a circle marker.
#Line marker color as read
#Line width should be 3
plt.plot(month_number,total_profit,color='r',marker='o',markerfacecolor='k',linestyle='--', linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.show()

# %%
#Exercise Question 3: Read all product sales data and show it  using a multiline plot
#Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
products=sales[['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']]
plt.plot(products,marker='o')
plt.legend(loc='upper left')
plt.xlabel('Month number')
plt.ylabel('Product')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#alternatively to the above
faceCremSalesData   = sales ['facecream'].tolist()
faceWashSalesData   = sales['facewash'].tolist()
toothPasteSalesData = sales ['toothpaste'].tolist()
bathingsoapSalesData   = sales ['bathingsoap'].tolist()
shampooSalesData   = sales ['shampoo'].tolist()
moisturizerSalesData = sales ['moisturizer'].tolist()

plt.plot(month_number, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(month_number, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(month_number, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(month_number, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(month_number, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(month_number, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.show()

# %%
#Exercise Question 4: Read toothpaste sales data of each month and show it using a scatter plot
#Also, add a grid in the plot. gridline style should “–“.
toothpastesales=sales['toothpaste']
plt.scatter(month_number,toothpastesales,label = 'Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend(loc='upper left')
plt.title(' Tooth paste Sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %%
#Exercise Question 5: Read face cream and facewash product sales data and show it using the bar chart
facecreamsales=sales['facecream']
facewashsales=sales['facewash']
plt.bar([a-0.25 for a in month_number],facecreamsales,width= 0.25,label='face cream sales',align='edge')
plt.bar([a+0.25 for a in month_number],facewashsales,width= -0.25,label='face wash sales',align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
plt.show()

# %%
#same plot as above
facecreamsales=sales['facecream']
facewashsales=sales['facewash']
plt.bar(month_number,facecreamsales,label='face cream sales')
plt.bar(month_number,facewashsales,label='face wash sales')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
plt.show()

# %%
#Exercise Question 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
bathingsoapsales=sales['bathingsoap']
plt.bar(month_number,bathingsoapsales,label='bathing soap sales',color='r')
plt.xlabel('Month number')
plt.ylabel('sales')
plt.legend(loc='upper left')
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Total sales for bathing soap')
plt.show( )

# %%
#Exercise Question 7: Read the total profit of each month and show it using the histogram to see most common profit ranges
#to investigate more
total_profit=sales['total_profit']
plt.hist(total_profit)
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <a list of 10 Patch objects>)

# %%
#Exercise Question 8: Calculate total sale data for last year for each product and show it using a Pie chart
#Note: In Pie chart display Number of units sold per year for each product in percentage.
labels=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
salesData   = [sales ['facecream'].sum(), sales ['facewash'].sum(), sales['toothpaste'].sum(), 
         sales ['bathingsoap'].sum(), sales ['shampoo'].sum(), sales ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %%
#Exercise Question 8: Calculate total sale data for last year for each product and show it using a Pie chart
#Note: In Pie chart display Number of units sold per year for each product in percentage.
labels=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
salesData   = [sales ['facecream'].sum(), sales ['facewash'].sum(), sales['toothpaste'].sum(), 
         sales ['bathingsoap'].sum(), sales ['shampoo'].sum(), sales ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels)
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %%
#Exercise Question 9: Read Bathing soap facewash of all months and display it using the Subplot

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()
bathingsoap   = df ['bathingsoap'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)
axarr[0].set_title('Sales data of  a Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='r', marker='o', linewidth=3)
axarr[1].set_title('Sales data of  a facewash')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-1f5fef9c552b> in <module>
#       1 #Exercise Question 9: Read Bathing soap facewash of all months and display it using the Subplot
#       2
# ----> 3 df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
#       4 monthList  = df ['month_number'].tolist()
#       5 bathingsoap   = df ['bathingsoap'].tolist()
#
# ...

# %%
#Exercise Question 10: Read all product sales data and show it using the stack plot
facecremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['m','c','r','k','g','y'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Alll product sales data using stack plot')
plt.legend(loc='upper left')
plt.show()

 Copy
